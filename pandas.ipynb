# %%
import pandas as pd

# %%
#list/numpy array/dictionary/set/tuple 
# series can be created from any of the above
 
data=[10,20,30,40,50,60,70]
data
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
s1=pd.Series(data)#creating a series from sequence
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2=pd.Series(['hello1','hello2','hello3'])
s2
# Out:
# 0    hello1
# 1    hello2
# 2    hello3
# dtype: object

# %%
# hello1 - string                   {in python}
# hello1 - unicode character string {in numpy}
# hello1 - object                   {in pandas}

# %%
# dataframe
df=pd.DataFrame(['hello1','hello2','hello3'])
df
# Out:
#         0
# 0  hello1
# 1  hello2
# 2  hello3

# %%
#create a data frame of two columns from a series

df={"one":pd.Series([1.0,2.0,3.0],index=["a","b","c"]),"two":pd.Series([1.0,2.0,3.0],index=["a","b","c"])}

df=pd.DataFrame(df)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0

# %%
# source files to import and use for creating a dataframe

# 1. .txt    - text document
# 2. .html   - hypertext markup language
# 3. .py     - python file
# 4. .ipynb  - interactive python notebook 
# 5. .xlsx   - excel spreadsheet
# 6. .csv    - coma seperated values
# 7. .tsv    - tab seperated values
# 8. .xml    - extensible markup language
# 9. .json   - javascript object notation

# %%
df=pd.read_table("/content/demo.txt")
df
# Out:
#    SL.NO UPPERCASE lowercase
# 0      1        AA        aa
# 1      2        BB        bb
# 2      3        CC        cc
# 3      4        DD        dd
# 4      5        EE        ee

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# methods to read the file
df=pd.read_csv("/content/50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# # KAGGLE website for datasets
# two methods
# 1.raw file(data is stored on cloud)(azure,aws-storage,googleapis,github)
# 2.download the file and upload it in the files section of the colab

# %%
#creating dataframe using raw file
df=pd.read_table("https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220609%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220609T012115Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df=pd.read_table("/content/fruit_data_with_colors.txt")
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
df.shape   #rows,columns
# Out:
# (59, 7)

# %%
df.size #total no of values in each axis(rows*columns)
# Out:
# 413

# %%
df.info() # complete information regarding data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#NaN - not a number(null value)
df.isnull().sum() #sum() will give u the sum of ll the null values in the row
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
df.isnull()
# Out:
#     fruit_label  fruit_name  fruit_subtype   mass  width  height  color_score
# 0         False       False          False  False  False   False        False
# 1         False       False          False  False  False   False        False
# 2         False       False          False  False  False   False        False
# 3         False       False          False  False  False   False        False
# 4         False       False          False  False  False   False        False
# 5         False       False          False  False  False   False        False
# 6         False       False          False  False  False   False        False
# 7         False       False          False  False  False   False        False
# 8         False       False          False  False  False   False        False
# 9         False       False          False  False  False   False        False
# 10        False       False          False  False  False   False        False
# ...

# %%
df.head() #prints first 5 rows
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.tail() #prints last 5 rows
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df.describe() #summary statistics of the dataframe
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
df[0:21] #print first 20 rows(inclusive:exclusive)
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.iloc[25:30,0:3] #purely integer based indexing
# Out:
#     fruit_label fruit_name     fruit_subtype
# 25            3     orange     spanish_jumbo
# 26            3     orange     spanish_jumbo
# 27            3     orange  selected_seconds
# 28            3     orange  selected_seconds
# 29            3     orange  selected_seconds

# %%
df.iloc[25:30,[5,2,6,1]]
# Out:
#     height     fruit_subtype  color_score fruit_name
# 25     9.2     spanish_jumbo         0.75     orange
# 26     9.2     spanish_jumbo         0.74     orange
# 27     9.2  selected_seconds         0.77     orange
# 28     7.1  selected_seconds         0.72     orange
# 29     7.4  selected_seconds         0.81     orange

# %%
fname=df.fruit_name #creates a series for this column
fname
# Out:
# 0        apple
# 1        apple
# 2        apple
# 3     mandarin
# 4     mandarin
# 5     mandarin
# 6     mandarin
# 7     mandarin
# 8        apple
# 9        apple
# 10       apple
# 11       apple
# 12       apple
# 13       apple
# 14       apple
# 15       apple
# 16       apple
# 17       apple
# 18       apple
# 19       apple
# 20       apple
# 21       apple
# 22       apple
# 23       apple
# 24      orange
# 25      orange
# 26      orange
# 27      orange
# 28      orange
# 29      orange
# 30      orange
# 31      orange
# 32      orange
# 33      orange
# 34      orange
# 35      orange
# 36      orange
# 37      orange
# 38      orange
# 39      orange
# 40      orange
# 41      orange
# 42      orange
# 43       lemon
# 44       lemon
# 45       lemon
# 46       lemon
# 47       lemon
# 48       lemon
# 49       lemon
# 50       lemon
# 51       lemon
# 52       lemon
# 53       lemon
# 54       lemon
# 55       lemon
# 56       lemon
# 57       lemon
# ...

# %%
fname=df.fruit_name.nunique() #count of the unique elemenets
fname
# Out:
# 4

# %%
fname=df.fruit_name.unique() #names of the unique elements
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fsize=df.groupby('fruit_name',sort=False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
fsize=df['fruit_name'].value_counts()
fsize
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
df['fruit_name'].value_counts().plot(kind='bar')

# %%
df['fruit_name'].value_counts().plot(kind='pie')

# %%
import matplotlib.pyplot as plt
plt.bar(fname,fsize)
# Out:
# <BarContainer object of 4 artists>

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
width1=df['width'] #series 1
height1=df['height'] #series2
plt.scatter(width1,height1)
